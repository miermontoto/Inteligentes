# %% [markdown]
# ## **Práctica 7: Deep learning 2 - Transferencia de aprendizaje en CNNs**
#
# Como hemos visto en la práctica anterior, las redes de neuronas convolucionales o simplemente **redes convolucionales** (CNNs, del inglés *convolutional neural networks*), son un tipo de redes neuronales profundas que utilizan imágenes como datos de entrada para resolver una tarea de clasificación o regresión.
#
# A continuación, veremos un ejemplo en el que utilizaremos una red pre-entrenada en ImageNet y realizaremos un ajuste de parámetros para el problema a resolver, utilizando la librería [TensorFlow](https://www.tensorflow.org/).

# %% [markdown]
# ### **1. Preparar los datos de entrenamiento**
#
# En esta práctica vamos a utilizar un conjunto para clasificación de imágenes denominado **Flowers recognition**, adaptado de la versión disponible en [Kaggle](https://www.kaggle.com/alxmamaev/flowers-recognition). Para ello, es necesario subir a Google Drive el fichero [`DL_flowers.zip`](https://drive.google.com/file/d/1pQYJJ9D8Ho9YoZGL0M-r2PA_8e2D3Gm4/view?usp=sharing) que contiene:
#
# *   Una carpeta `images` con 4315 imágenes de flores correspondientes a cinco clases (*daisy*, *dandelion*, *rose*, *sunflower*, *tulip*).
# *   Un fichero `labels.csv` con los nombres de todas las imágenes (columna *image_name*) y la clase a la que pertenece cada imagen (columna *class*).

# %%
import pandas as pd
from google.colab import drive

# Montar el Google Drive en el directorio del proyecto y descomprimir el fichero con los datos
drive.mount('/content/gdrive')
# !unzip -n '/content/gdrive/My Drive/SSII/DL_flowers.zip'  # ruta al fichero comprimido

# Especificar las rutas al directorio con las imágenes y al fichero con las etiquetas
data_path = 'flowers/'
imgs_path = data_path + "images/"
labels_path = data_path + "labels.csv"

# Leer el fichero CSV con las etiquetas
labels = pd.read_csv(labels_path, dtype = {"class": "category"})
# Out:
# Mounted at /content/gdrive
# Archive:  /content/gdrive/My Drive/SSII/DL_flowers.zip
#    creating: flowers/
#   inflating: flowers/labels.csv
#    creating: flowers/images/
#   inflating: flowers/images/16209331331_343c899d38.jpg
#   inflating: flowers/images/6204049536_1ac4f09232_n.jpg
#   inflating: flowers/images/9965757055_ff01b5ee6f_n.jpg
#   inflating: flowers/images/5001848317_b33d17ab7a_n.jpg
#   inflating: flowers/images/18828283553_e46504ae38.jpg
#   inflating: flowers/images/18302701228_2b5790b199_n.jpg
#   inflating: flowers/images/461632542_0387557eff.jpg
#   inflating: flowers/images/14167534527_781ceb1b7a_n.jpg
#   inflating: flowers/images/5700466891_2bcb17fa68_n.jpg
#   inflating: flowers/images/14087792403_f34f37ba3b_m.jpg
#   inflating: flowers/images/8021568040_f891223c44_n.jpg
#   inflating: flowers/images/34718882165_68cdc9def9_n.jpg
#   inflating: flowers/images/5777669976_a205f61e5b.jpg
#   inflating: flowers/images/3446285408_4be9c0fded_m.jpg
#   inflating: flowers/images/4572738670_4787a11058_n.jpg
#   inflating: flowers/images/4860145119_b1c3cbaa4e_n.jpg
#   inflating: flowers/images/15011625580_7974c44bce.jpg
#   inflating: flowers/images/16282277874_b92776b194.jpg
#   inflating: flowers/images/17953368844_be3d18cf30_m.jpg
#   inflating: flowers/images/8983268106_dc913d17d8_m.jpg
#   inflating: flowers/images/9472854850_fc9e1db673.jpg
#   inflating: flowers/images/7166616072_1233051d98_n.jpg
#   inflating: flowers/images/4065883015_4bb6010cb7_n.jpg
#   inflating: flowers/images/8842317179_d59cf218cb_n.jpg
#   inflating: flowers/images/5002458392_f465ed905e_n.jpg
#   inflating: flowers/images/10486992895_20b344ce2d_n.jpg
#   inflating: flowers/images/2834890466_1cf220fba1.jpg
#   inflating: flowers/images/5004121118_e9393e60d0_n.jpg
#   inflating: flowers/images/15066430311_fb57fa92b0_m.jpg
#   inflating: flowers/images/13953090784_0c7d7a904e.jpg

# %% [markdown]
# A continuación, utilizaremos el método [train_test_split()](http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html), disponible en la librería `scikit-learn`, para dividir los datos en tres particiones: **entrenamiento, validación y test**. En este ejemplo, utilizaremos el 70% de las imágenes para entrenamiento, el 15% para validación y el 15% para test.

# %%
from sklearn.model_selection import train_test_split

# Crear las tres particiones de datos: entrenamiento, validación y test
seed = 0
train_data, test_data = train_test_split(labels, test_size=0.3, random_state=seed)
dev_data, test_data = train_test_split(test_data, test_size=0.5, random_state=seed)

# Actualizar los índices de cada partición
train_data = train_data.reset_index(drop=True)
dev_data = dev_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

# %% [markdown]
# A continuación, utilizaremos [`ImageDataGenerator()`](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator) para generar los *batches* de las tres particiones.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Preparar los datos utilizando normalización (rescale)
datagen = ImageDataGenerator(rescale=1./255)

# Especificar información dependiente del conjunto de datos
classes = ["0","1","2","3","4"]  # clases del problema
n_classes = len(classes)         # número de clases
img_width = img_height = 224     # dimensiones de la imagen
x_col = 'image_name'             # nombres de las columnas en el fichero CSV
y_col = 'class'

# Generar los batches con los datos para las tres particiones
batch_size = 128  # tamaño del batch
train_generator = datagen.flow_from_dataframe(dataframe=train_data, directory=imgs_path, x_col=x_col, y_col=y_col,
                                              class_mode="categorical", target_size=(img_width,img_height),
                                              batch_size=batch_size, classes=classes)
dev_generator = datagen.flow_from_dataframe(dataframe=dev_data, directory=imgs_path, x_col=x_col, y_col=y_col,
                                            class_mode="categorical", target_size=(img_width,img_height),
                                            batch_size=batch_size, classes=classes)
test_generator = datagen.flow_from_dataframe(dataframe=test_data, directory=imgs_path, x_col=x_col, y_col=y_col,
                                             class_mode="categorical", target_size=(img_width,img_height),
                                             batch_size=batch_size, classes=classes)
# Out:
# Found 3020 validated image filenames belonging to 5 classes.
# Found 647 validated image filenames belonging to 5 classes.
# Found 648 validated image filenames belonging to 5 classes.

# %% [markdown]
# ### **2. Crear una CNN**
#
# Una alternativa a crear una CNN y entrenarla desde cero es utilizar modelos pre-entrenados con grandes conjuntos de datos. Para ello, vamos a utilizar el modelo [InceptionV3](https://www.tensorflow.org/api_docs/python/tf/keras/applications/inception_v3) pre-entrenado con [ImageNet](https://www.image-net.org/), una base de datos con más de 14 millones de imágenes correspondientes a más de 20 mil clases. En la librería `TensorFlow` puedes encontrar otros [modelos pre-entrenados](https://www.tensorflow.org/api_docs/python/tf/keras/applications).
#
# En primer lugar, cargaremos la base convolucional (`include_top=False`) de una InceptionV3 pre-entrenada con ImageNet. A continuación, le añadiremos unas capas completamente conectadas que nos permitan resolver nuestro problema de clasificación multi-clase (5 clases). Los parámetros de las nuevas capas se inicializarán aleatoriamente y se aprenderán durante el proceso de entrenamiento. Con respecto al resto de parámetros del modelo, permacerán fijos o *congelados* (`trainable=False`); es decir, los parámetros de las capas de la base convolucional serán los del modelo base pre-entrenado con ImageNet y no sufrirán ajustes durante el proceso de entrenamiento.

# %%
from tensorflow.keras import applications
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout

def get_model():

  # Cargar la base convolucional del modelo InceptionV3 pre-entrenado en ImageNet
  base_model = applications.InceptionV3(weights='imagenet', include_top=False, input_shape=(img_width,img_height,3))

  # Ajustar los parámetros de las nuevas capas del modelo, dejando fijos los parámetros del resto de capas
  for layer in base_model.layers:
      layer.trainable = False   # por defecto, layer.trainable es True

  # Añadir nuevas capas a continuación de la base convolucional, para resolver la tarea de aprendizaje
  x = base_model.output
  x = GlobalAveragePooling2D()(x)
  x = Dropout(0.25)(x)
  x = Dense(1024, activation='relu')(x)

  # Añadir una última capa completamente conectada con 5 neuronas (número de clases) para obtener la salida de la red
  predictions = Dense(n_classes, activation='softmax')(x)

  # Crear el modelo final e imprimir su representacion en modo texto
  model = Model(inputs=[base_model.input], outputs=[predictions])
  model.summary()

  return model

# %% [markdown]
# ### **3. Entrenar una CNN**
#
# Una vez definida la arquitectura de la CNN (la base convolucional de InceptionV3 + una capa oculta de 1024 neuronas + una capa de salida), el siguiente paso es configurar el modelo para el entrenamiento. Para ello utilizaremos el método [`compile()`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#compile), siendo estos algunos de sus parámetros más relevantes:
#
# * *optimizer*: nombre del optimizador (`Adam`, `RMSProp`, etc.) y tasa de aprendizaje (`learning_rate`). Ver [tf.keras.optimizers](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers).
# * *loss*: función de pérdida (`mean_squared_error`, `binary_crossentropy`, `categorical_crossentropy`, etc.). Ver [tf.keras.losses](https://www.tensorflow.org/api_docs/python/tf/keras/losses).
# * *metrics*: métricas que evaluará el modelo durante el entrenamiento y la validación (`accuracy`, etc.). Ver [tf.keras.metrics](https://www.tensorflow.org/api_docs/python/tf/keras/metrics).

# %%
from tensorflow.keras import optimizers

# Crear el modelo
model = get_model()

# Configurar el proceso de aprendizaje
model.compile(loss='categorical_crossentropy',                 # función de pérdida para problemas de clasificación multi-clase
              optimizer=optimizers.AdamW(learning_rate=0.005),
              metrics=['accuracy'])
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_470 (Conv2D)            (None, 111, 111, 32  864         ['input_6[0][0]']
#                                 )
#
#  batch_normalization_470 (Batch  (None, 111, 111, 32  96         ['conv2d_470[0][0]']
#  Normalization)                 )
#
#  activation_470 (Activation)    (None, 111, 111, 32  0           ['batch_normalization_470[0][0]']
#                                 )
#
#  conv2d_471 (Conv2D)            (None, 109, 109, 32  9216        ['activation_470[0][0]']
#                                 )
#
#  batch_normalization_471 (Batch  (None, 109, 109, 32  96         ['conv2d_471[0][0]']
#  Normalization)                 )
#
#  activation_471 (Activation)    (None, 109, 109, 32  0           ['batch_normalization_471[0][0]']
#                                 )
#
#  conv2d_472 (Conv2D)            (None, 109, 109, 64  18432       ['activation_471[0][0]']
#                                 )
#
#  batch_normalization_472 (Batch  (None, 109, 109, 64  192        ['conv2d_472[0][0]']
#  Normalization)                 )
#
#  activation_472 (Activation)    (None, 109, 109, 64  0           ['batch_normalization_472[0][0]']
#                                 )
#
#  max_pooling2d_20 (MaxPooling2D  (None, 54, 54, 64)  0           ['activation_472[0][0]']
#  )
#
#  conv2d_473 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_20[0][0]']
#
#  batch_normalization_473 (Batch  (None, 54, 54, 80)  240         ['conv2d_473[0][0]']
#  Normalization)
#
#  activation_473 (Activation)    (None, 54, 54, 80)   0           ['batch_normalization_473[0][0]']
#
#  conv2d_474 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_473[0][0]']
#
#  batch_normalization_474 (Batch  (None, 52, 52, 192)  576        ['conv2d_474[0][0]']
#  Normalization)
#
#  activation_474 (Activation)    (None, 52, 52, 192)  0           ['batch_normalization_474[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 25, 25, 192)  0          ['activation_474[0][0]']
#  )
#
#  conv2d_478 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_21[0][0]']
#
#  batch_normalization_478 (Batch  (None, 25, 25, 64)  192         ['conv2d_478[0][0]']
#  Normalization)
#
#  activation_478 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_478[0][0]']
#
#  conv2d_476 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_21[0][0]']
#
#  conv2d_479 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_478[0][0]']
#
#  batch_normalization_476 (Batch  (None, 25, 25, 48)  144         ['conv2d_476[0][0]']
#  Normalization)
#
#  batch_normalization_479 (Batch  (None, 25, 25, 96)  288         ['conv2d_479[0][0]']
#  Normalization)
#
#  activation_476 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_476[0][0]']
#
#  activation_479 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_479[0][0]']
#
#  average_pooling2d_45 (AverageP  (None, 25, 25, 192)  0          ['max_pooling2d_21[0][0]']
#  ooling2D)
#
#  conv2d_475 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_21[0][0]']
#
#  conv2d_477 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_476[0][0]']
#
#  conv2d_480 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_479[0][0]']
#
#  conv2d_481 (Conv2D)            (None, 25, 25, 32)   6144        ['average_pooling2d_45[0][0]']
#
#  batch_normalization_475 (Batch  (None, 25, 25, 64)  192         ['conv2d_475[0][0]']
#  Normalization)
#
#  batch_normalization_477 (Batch  (None, 25, 25, 64)  192         ['conv2d_477[0][0]']
#  Normalization)
#
#  batch_normalization_480 (Batch  (None, 25, 25, 96)  288         ['conv2d_480[0][0]']
#  Normalization)
#
#  batch_normalization_481 (Batch  (None, 25, 25, 32)  96          ['conv2d_481[0][0]']
#  Normalization)
#
#  activation_475 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_475[0][0]']
#
#  activation_477 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_477[0][0]']
#
#  activation_480 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_480[0][0]']
#
#  activation_481 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_481[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_475[0][0]',
#                                                                   'activation_477[0][0]',
#                                                                   'activation_480[0][0]',
#                                                                   'activation_481[0][0]']
#
#  conv2d_485 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_485 (Batch  (None, 25, 25, 64)  192         ['conv2d_485[0][0]']
#  Normalization)
#
#  activation_485 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_485[0][0]']
#
#  conv2d_483 (Conv2D)            (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_486 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_485[0][0]']
#
#  batch_normalization_483 (Batch  (None, 25, 25, 48)  144         ['conv2d_483[0][0]']
#  Normalization)
#
#  batch_normalization_486 (Batch  (None, 25, 25, 96)  288         ['conv2d_486[0][0]']
#  Normalization)
#
#  activation_483 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_483[0][0]']
#
#  activation_486 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_486[0][0]']
#
#  average_pooling2d_46 (AverageP  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_482 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_484 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_483[0][0]']
#
#  conv2d_487 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_486[0][0]']
#
#  conv2d_488 (Conv2D)            (None, 25, 25, 64)   16384       ['average_pooling2d_46[0][0]']
#
#  batch_normalization_482 (Batch  (None, 25, 25, 64)  192         ['conv2d_482[0][0]']
#  Normalization)
#
#  batch_normalization_484 (Batch  (None, 25, 25, 64)  192         ['conv2d_484[0][0]']
#  Normalization)
#
#  batch_normalization_487 (Batch  (None, 25, 25, 96)  288         ['conv2d_487[0][0]']
#  Normalization)
#
#  batch_normalization_488 (Batch  (None, 25, 25, 64)  192         ['conv2d_488[0][0]']
#  Normalization)
#
#  activation_482 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_482[0][0]']
#
#  activation_484 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_484[0][0]']
#
#  activation_487 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_487[0][0]']
#
#  activation_488 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_488[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_482[0][0]',
#                                                                   'activation_484[0][0]',
#                                                                   'activation_487[0][0]',
#                                                                   'activation_488[0][0]']
#
#  conv2d_492 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_492 (Batch  (None, 25, 25, 64)  192         ['conv2d_492[0][0]']
#  Normalization)
#
#  activation_492 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_492[0][0]']
#
#  conv2d_490 (Conv2D)            (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_493 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_492[0][0]']
#
#  batch_normalization_490 (Batch  (None, 25, 25, 48)  144         ['conv2d_490[0][0]']
#  Normalization)
#
#  batch_normalization_493 (Batch  (None, 25, 25, 96)  288         ['conv2d_493[0][0]']
#  Normalization)
#
#  activation_490 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_490[0][0]']
#
#  activation_493 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_493[0][0]']
#
#  average_pooling2d_47 (AverageP  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_489 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_491 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_490[0][0]']
#
#  conv2d_494 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_493[0][0]']
#
#  conv2d_495 (Conv2D)            (None, 25, 25, 64)   18432       ['average_pooling2d_47[0][0]']
#
#  batch_normalization_489 (Batch  (None, 25, 25, 64)  192         ['conv2d_489[0][0]']
#  Normalization)
#
#  batch_normalization_491 (Batch  (None, 25, 25, 64)  192         ['conv2d_491[0][0]']
#  Normalization)
#
#  batch_normalization_494 (Batch  (None, 25, 25, 96)  288         ['conv2d_494[0][0]']
#  Normalization)
#
#  batch_normalization_495 (Batch  (None, 25, 25, 64)  192         ['conv2d_495[0][0]']
#  Normalization)
#
#  activation_489 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_489[0][0]']
#
#  activation_491 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_491[0][0]']
#
#  activation_494 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_494[0][0]']
#
#  activation_495 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_495[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_489[0][0]',
#                                                                   'activation_491[0][0]',
#                                                                   'activation_494[0][0]',
#                                                                   'activation_495[0][0]']
#
#  conv2d_497 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_497 (Batch  (None, 25, 25, 64)  192         ['conv2d_497[0][0]']
#  Normalization)
#
#  activation_497 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_497[0][0]']
#
#  conv2d_498 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_497[0][0]']
#
#  batch_normalization_498 (Batch  (None, 25, 25, 96)  288         ['conv2d_498[0][0]']
#  Normalization)
#
#  activation_498 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_498[0][0]']
#
#  conv2d_496 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_499 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_498[0][0]']
#
#  batch_normalization_496 (Batch  (None, 12, 12, 384)  1152       ['conv2d_496[0][0]']
#  Normalization)
#
#  batch_normalization_499 (Batch  (None, 12, 12, 96)  288         ['conv2d_499[0][0]']
#  Normalization)
#
#  activation_496 (Activation)    (None, 12, 12, 384)  0           ['batch_normalization_496[0][0]']
#
#  activation_499 (Activation)    (None, 12, 12, 96)   0           ['batch_normalization_499[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_496[0][0]',
#                                                                   'activation_499[0][0]',
#                                                                   'max_pooling2d_22[0][0]']
#
#  conv2d_504 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_504 (Batch  (None, 12, 12, 128)  384        ['conv2d_504[0][0]']
#  Normalization)
#
#  activation_504 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_504[0][0]']
#
#  conv2d_505 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_504[0][0]']
#
#  batch_normalization_505 (Batch  (None, 12, 12, 128)  384        ['conv2d_505[0][0]']
#  Normalization)
#
#  activation_505 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_505[0][0]']
#
#  conv2d_501 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_506 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_505[0][0]']
#
#  batch_normalization_501 (Batch  (None, 12, 12, 128)  384        ['conv2d_501[0][0]']
#  Normalization)
#
#  batch_normalization_506 (Batch  (None, 12, 12, 128)  384        ['conv2d_506[0][0]']
#  Normalization)
#
#  activation_501 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_501[0][0]']
#
#  activation_506 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_506[0][0]']
#
#  conv2d_502 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_501[0][0]']
#
#  conv2d_507 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_506[0][0]']
#
#  batch_normalization_502 (Batch  (None, 12, 12, 128)  384        ['conv2d_502[0][0]']
#  Normalization)
#
#  batch_normalization_507 (Batch  (None, 12, 12, 128)  384        ['conv2d_507[0][0]']
#  Normalization)
#
#  activation_502 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_502[0][0]']
#
#  activation_507 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_507[0][0]']
#
#  average_pooling2d_48 (AverageP  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_500 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_503 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_502[0][0]']
#
#  conv2d_508 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_507[0][0]']
#
#  conv2d_509 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_48[0][0]']
#
#  batch_normalization_500 (Batch  (None, 12, 12, 192)  576        ['conv2d_500[0][0]']
#  Normalization)
#
#  batch_normalization_503 (Batch  (None, 12, 12, 192)  576        ['conv2d_503[0][0]']
#  Normalization)
#
#  batch_normalization_508 (Batch  (None, 12, 12, 192)  576        ['conv2d_508[0][0]']
#  Normalization)
#
#  batch_normalization_509 (Batch  (None, 12, 12, 192)  576        ['conv2d_509[0][0]']
#  Normalization)
#
#  activation_500 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_500[0][0]']
#
#  activation_503 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_503[0][0]']
#
#  activation_508 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_508[0][0]']
#
#  activation_509 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_509[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_500[0][0]',
#                                                                   'activation_503[0][0]',
#                                                                   'activation_508[0][0]',
#                                                                   'activation_509[0][0]']
#
#  conv2d_514 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_514 (Batch  (None, 12, 12, 160)  480        ['conv2d_514[0][0]']
#  Normalization)
#
#  activation_514 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_514[0][0]']
#
#  conv2d_515 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_514[0][0]']
#
#  batch_normalization_515 (Batch  (None, 12, 12, 160)  480        ['conv2d_515[0][0]']
#  Normalization)
#
#  activation_515 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_515[0][0]']
#
#  conv2d_511 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_516 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_515[0][0]']
#
#  batch_normalization_511 (Batch  (None, 12, 12, 160)  480        ['conv2d_511[0][0]']
#  Normalization)
#
#  batch_normalization_516 (Batch  (None, 12, 12, 160)  480        ['conv2d_516[0][0]']
#  Normalization)
#
#  activation_511 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_511[0][0]']
#
#  activation_516 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_516[0][0]']
#
#  conv2d_512 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_511[0][0]']
#
#  conv2d_517 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_516[0][0]']
#
#  batch_normalization_512 (Batch  (None, 12, 12, 160)  480        ['conv2d_512[0][0]']
#  Normalization)
#
#  batch_normalization_517 (Batch  (None, 12, 12, 160)  480        ['conv2d_517[0][0]']
#  Normalization)
#
#  activation_512 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_512[0][0]']
#
#  activation_517 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_517[0][0]']
#
#  average_pooling2d_49 (AverageP  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_510 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_513 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_512[0][0]']
#
#  conv2d_518 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_517[0][0]']
#
#  conv2d_519 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_49[0][0]']
#
#  batch_normalization_510 (Batch  (None, 12, 12, 192)  576        ['conv2d_510[0][0]']
#  Normalization)
#
#  batch_normalization_513 (Batch  (None, 12, 12, 192)  576        ['conv2d_513[0][0]']
#  Normalization)
#
#  batch_normalization_518 (Batch  (None, 12, 12, 192)  576        ['conv2d_518[0][0]']
#  Normalization)
#
#  batch_normalization_519 (Batch  (None, 12, 12, 192)  576        ['conv2d_519[0][0]']
#  Normalization)
#
#  activation_510 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_510[0][0]']
#
#  activation_513 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_513[0][0]']
#
#  activation_518 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_518[0][0]']
#
#  activation_519 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_519[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_510[0][0]',
#                                                                   'activation_513[0][0]',
#                                                                   'activation_518[0][0]',
#                                                                   'activation_519[0][0]']
#
#  conv2d_524 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_524 (Batch  (None, 12, 12, 160)  480        ['conv2d_524[0][0]']
#  Normalization)
#
#  activation_524 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_524[0][0]']
#
#  conv2d_525 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_524[0][0]']
#
#  batch_normalization_525 (Batch  (None, 12, 12, 160)  480        ['conv2d_525[0][0]']
#  Normalization)
#
#  activation_525 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_525[0][0]']
#
#  conv2d_521 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_526 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_525[0][0]']
#
#  batch_normalization_521 (Batch  (None, 12, 12, 160)  480        ['conv2d_521[0][0]']
#  Normalization)
#
#  batch_normalization_526 (Batch  (None, 12, 12, 160)  480        ['conv2d_526[0][0]']
#  Normalization)
#
#  activation_521 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_521[0][0]']
#
#  activation_526 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_526[0][0]']
#
#  conv2d_522 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_521[0][0]']
#
#  conv2d_527 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_526[0][0]']
#
#  batch_normalization_522 (Batch  (None, 12, 12, 160)  480        ['conv2d_522[0][0]']
#  Normalization)
#
#  batch_normalization_527 (Batch  (None, 12, 12, 160)  480        ['conv2d_527[0][0]']
#  Normalization)
#
#  activation_522 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_522[0][0]']
#
#  activation_527 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_527[0][0]']
#
#  average_pooling2d_50 (AverageP  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_520 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_523 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_522[0][0]']
#
#  conv2d_528 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_527[0][0]']
#
#  conv2d_529 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_50[0][0]']
#
#  batch_normalization_520 (Batch  (None, 12, 12, 192)  576        ['conv2d_520[0][0]']
#  Normalization)
#
#  batch_normalization_523 (Batch  (None, 12, 12, 192)  576        ['conv2d_523[0][0]']
#  Normalization)
#
#  batch_normalization_528 (Batch  (None, 12, 12, 192)  576        ['conv2d_528[0][0]']
#  Normalization)
#
#  batch_normalization_529 (Batch  (None, 12, 12, 192)  576        ['conv2d_529[0][0]']
#  Normalization)
#
#  activation_520 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_520[0][0]']
#
#  activation_523 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_523[0][0]']
#
# ...
#
#  conv2d_547 (Conv2D)            (None, 5, 5, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_551 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_550[0][0]']
#
#  batch_normalization_547 (Batch  (None, 5, 5, 384)   1152        ['conv2d_547[0][0]']
#  Normalization)
#
#  batch_normalization_551 (Batch  (None, 5, 5, 384)   1152        ['conv2d_551[0][0]']
#  Normalization)
#
#  activation_547 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_547[0][0]']
#
#  activation_551 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_551[0][0]']
#
#  conv2d_548 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_547[0][0]']
#
#  conv2d_549 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_547[0][0]']
#
#  conv2d_552 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_551[0][0]']
#
#  conv2d_553 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_551[0][0]']
#
#  average_pooling2d_52 (AverageP  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_546 (Conv2D)            (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_548 (Batch  (None, 5, 5, 384)   1152        ['conv2d_548[0][0]']
#  Normalization)
#
#  batch_normalization_549 (Batch  (None, 5, 5, 384)   1152        ['conv2d_549[0][0]']
#  Normalization)
#
#  batch_normalization_552 (Batch  (None, 5, 5, 384)   1152        ['conv2d_552[0][0]']
#  Normalization)
#
#  batch_normalization_553 (Batch  (None, 5, 5, 384)   1152        ['conv2d_553[0][0]']
#  Normalization)
#
#  conv2d_554 (Conv2D)            (None, 5, 5, 192)    245760      ['average_pooling2d_52[0][0]']
#
#  batch_normalization_546 (Batch  (None, 5, 5, 320)   960         ['conv2d_546[0][0]']
#  Normalization)
#
#  activation_548 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_548[0][0]']
#
#  activation_549 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_549[0][0]']
#
#  activation_552 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_552[0][0]']
#
#  activation_553 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_553[0][0]']
#
#  batch_normalization_554 (Batch  (None, 5, 5, 192)   576         ['conv2d_554[0][0]']
#  Normalization)
#
#  activation_546 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_546[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_548[0][0]',
#                                                                   'activation_549[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 5, 5, 768)    0           ['activation_552[0][0]',
#                                                                   'activation_553[0][0]']
#
#  activation_554 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_554[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_546[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_10[0][0]',
#                                                                   'activation_554[0][0]']
#
#  conv2d_559 (Conv2D)            (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_559 (Batch  (None, 5, 5, 448)   1344        ['conv2d_559[0][0]']
#  Normalization)
#
#  activation_559 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_559[0][0]']
#
#  conv2d_556 (Conv2D)            (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_560 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_559[0][0]']
#
#  batch_normalization_556 (Batch  (None, 5, 5, 384)   1152        ['conv2d_556[0][0]']
#  Normalization)
#
#  batch_normalization_560 (Batch  (None, 5, 5, 384)   1152        ['conv2d_560[0][0]']
#  Normalization)
#
#  activation_556 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_556[0][0]']
#
#  activation_560 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_560[0][0]']
#
#  conv2d_557 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_556[0][0]']
#
#  conv2d_558 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_556[0][0]']
#
#  conv2d_561 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_560[0][0]']
#
#  conv2d_562 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_560[0][0]']
#
#  average_pooling2d_53 (AverageP  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_555 (Conv2D)            (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_557 (Batch  (None, 5, 5, 384)   1152        ['conv2d_557[0][0]']
#  Normalization)
#
#  batch_normalization_558 (Batch  (None, 5, 5, 384)   1152        ['conv2d_558[0][0]']
#  Normalization)
#
#  batch_normalization_561 (Batch  (None, 5, 5, 384)   1152        ['conv2d_561[0][0]']
#  Normalization)
#
#  batch_normalization_562 (Batch  (None, 5, 5, 384)   1152        ['conv2d_562[0][0]']
#  Normalization)
#
#  conv2d_563 (Conv2D)            (None, 5, 5, 192)    393216      ['average_pooling2d_53[0][0]']
#
#  batch_normalization_555 (Batch  (None, 5, 5, 320)   960         ['conv2d_555[0][0]']
#  Normalization)
#
#  activation_557 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_557[0][0]']
#
#  activation_558 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_558[0][0]']
#
#  activation_561 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_561[0][0]']
#
#  activation_562 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_562[0][0]']
#
#  batch_normalization_563 (Batch  (None, 5, 5, 192)   576         ['conv2d_563[0][0]']
#  Normalization)
#
#  activation_555 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_555[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_557[0][0]',
#                                                                   'activation_558[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 5, 5, 768)    0           ['activation_561[0][0]',
#                                                                   'activation_562[0][0]']
#
#  activation_563 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_563[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_555[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_11[0][0]',
#                                                                   'activation_563[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 2048)        0           ['mixed10[0][0]']
#  obalAveragePooling2D)
#
#  dropout_4 (Dropout)            (None, 2048)         0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 1024)         2098176     ['dropout_4[0][0]']
#
#  dense_11 (Dense)               (None, 5)            5125        ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 23,906,085
# Trainable params: 2,103,301
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %% [markdown]
# A continuación, entrenaremos el modelo para buscar los parámetros que hagan mínima la función de pérdida. Para ello utilizaremos el método [`fit()`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#fit), que necesita que le suministremos los datos de entrenamiento y validación, el número de *epochs* y el tamaño de *batch* (para calcular el número de *steps_per_epoch*).

# %%
# Entrenar el modelo con los datos preparados previamente
model.fit(train_generator,
          epochs=15,   # número de epochs
          verbose=2,  # muestra información del error al finalizar cada epoch
          steps_per_epoch=len(train_data)/batch_size,
          validation_data=dev_generator,
          validation_steps=len(dev_data)/batch_size)
# Out:
# Epoch 1/15
# 23/23 - 19s - loss: 0.1415 - accuracy: 0.9487 - val_loss: 0.4184 - val_accuracy: 0.8609 - 19s/epoch - 816ms/step
# Epoch 2/15
# 23/23 - 16s - loss: 0.1193 - accuracy: 0.9553 - val_loss: 0.4118 - val_accuracy: 0.8702 - 16s/epoch - 684ms/step
# Epoch 3/15
# 23/23 - 16s - loss: 0.1229 - accuracy: 0.9513 - val_loss: 0.4151 - val_accuracy: 0.8779 - 16s/epoch - 683ms/step
# Epoch 4/15
# 23/23 - 16s - loss: 0.1001 - accuracy: 0.9623 - val_loss: 0.4212 - val_accuracy: 0.8733 - 16s/epoch - 680ms/step
# Epoch 5/15
# 23/23 - 16s - loss: 0.0860 - accuracy: 0.9732 - val_loss: 0.4931 - val_accuracy: 0.8686 - 16s/epoch - 679ms/step
# Epoch 6/15
# 23/23 - 16s - loss: 0.0881 - accuracy: 0.9672 - val_loss: 0.4286 - val_accuracy: 0.8764 - 16s/epoch - 674ms/step
# Epoch 7/15
# 23/23 - 17s - loss: 0.0795 - accuracy: 0.9755 - val_loss: 0.4357 - val_accuracy: 0.8841 - 17s/epoch - 700ms/step
# Epoch 8/15
# 23/23 - 16s - loss: 0.0784 - accuracy: 0.9715 - val_loss: 0.4700 - val_accuracy: 0.8702 - 16s/epoch - 679ms/step
# Epoch 9/15
# 23/23 - 18s - loss: 0.0730 - accuracy: 0.9722 - val_loss: 0.5360 - val_accuracy: 0.8640 - 18s/epoch - 775ms/step
# Epoch 10/15
# 23/23 - 16s - loss: 0.0760 - accuracy: 0.9748 - val_loss: 0.4582 - val_accuracy: 0.8764 - 16s/epoch - 680ms/step
# Epoch 11/15
# 23/23 - 16s - loss: 0.0688 - accuracy: 0.9758 - val_loss: 0.5024 - val_accuracy: 0.8748 - 16s/epoch - 679ms/step
# Epoch 12/15
# 23/23 - 16s - loss: 0.0562 - accuracy: 0.9798 - val_loss: 0.4775 - val_accuracy: 0.8717 - 16s/epoch - 681ms/step
# Epoch 13/15
# 23/23 - 16s - loss: 0.0489 - accuracy: 0.9831 - val_loss: 0.5261 - val_accuracy: 0.8779 - 16s/epoch - 677ms/step
# Epoch 14/15
# 23/23 - 18s - loss: 0.0592 - accuracy: 0.9815 - val_loss: 0.5018 - val_accuracy: 0.8671 - 18s/epoch - 775ms/step
# Epoch 15/15
# 23/23 - 16s - loss: 0.0452 - accuracy: 0.9841 - val_loss: 0.5759 - val_accuracy: 0.8702 - 16s/epoch - 676ms/step

# %% [markdown]
# ### **4. Evaluar una CNN**
#
# Hemos visto cómo crear y entrenar una CNN a partir de un modelo pre-entrenado, utilizando una configuración de hiperparámetros que no necesariamente es la mejor. Lo ideal sería realizar una búsqueda de hiperparámetros y, una vez obtenida la mejor configuración, evaluar el modelo sobre el conjunto de test y así obtener el resultado final.
#
# A continuación, se muestra el código para evaluar el modelo final en el conjunto de test. Para ello utilizaremos el método [`evaluate()`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#evaluate) que necesita que le suministremos los datos de test y el tamaño del *batch* (para calcular el número de `steps`).

# %%
# Evaluar el modelo en el conjunto de test
test_loss, test_acc = model.evaluate(test_generator, steps=len(test_data)/batch_size, verbose=1)
print("test_loss: %.4f, test_acc: %.4f" % (test_loss, test_acc))
# Out:
# 5/5 [==============================] - 4s 640ms/step - loss: 0.6234 - accuracy: 0.8549
# test_loss: 0.6234, test_acc: 0.8549

# %% [markdown]
# Por último, además de analizar el error obtenido, podemos utilizar el modelo entrenado para hacer predicciones. Para ello utilizaremos el método [`predict()`](https://www.tensorflow.org/api_docs/python/tf/keras/Model#predict), al que le suministraremos los datos sobre los que realizar las predicciones (en este ejemplo, los datos de test).

# %%
import numpy as np

# Obtener las predicciones para todos los ejemplos del conjunto de test
predictions = model.predict(test_generator, verbose=1)

# Imprimir la predicción para los dos primeros ejemplos (los valores obtenidos representan las probabilidades para cada una de las 5 clases)
for i in range(0,2):
  print("\n Ejemplo", i)
  print("\t Probabilidades para las 5 clases:", predictions[i])
  print("\t Clase predicha: %i, Probabilidad: %.4f" % (np.argmax([predictions[i]]), np.max(predictions[i])))
# Out:
# 6/6 [==============================] - 3s 457ms/step
#
#  Ejemplo 0
# 	 Probabilidades para las 5 clases: [1.5659738e-04 9.9859601e-01 5.5620632e-07 1.2464238e-03 4.4701596e-07]
# 	 Clase predicha: 1, Probabilidad: 0.9986
#
#  Ejemplo 1
# 	 Probabilidades para las 5 clases: [3.9250252e-04 1.2257758e-05 3.0080109e-05 5.0268336e-03 9.9453837e-01]
# 	 Clase predicha: 4, Probabilidad: 0.9945

# %% [markdown]
# ### **5. Pruebas**
#
# Realiza una serie de pruebas con diferentes configuraciones de hiperparámetros (tasa de aprendizaje, optimizador) e intenta mejorar los resultados. Prueba también a modificar la arquitectura utilizando otras capas en la parte final del modelo (*top*) e incluso cargando otras [CNNs pre-entrenadas con ImageNet](https://www.tensorflow.org/api_docs/python/tf/keras/applications).
#
# En lugar de que el modelo solamente aprenda los parámetros de las capas nuevas, es posible hacer *fine-tuning* de los parámetros de todas las capas (o bien seleccionar algunas concretas). Para ello basta modificar el parámetro *trainable* de las diferentes capas.
#
# También puedes aplicar técnicas de *data augmentation*, modificando los parámetros del método [`ImageDataGenerator()`](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator); y técnicas para prevenir el sobreajuste utilizando, por ejemplo, la [capa dropout](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout).
